# %% [markdown]
# ## predictive modelling base line code

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Sample data
import numpy as np
x_train = np.random.rand(1000, 10)  # 1000 samples, 10 features
y_train = np.random.rand(1000, 1)   # 1000 target values

# Define the model
model = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(10,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)  # Output layer for regression
])

# Compile the model
model.compile(
    optimizer='adam',                # Optimizer
    loss='mse',                      # Loss function
    metrics=['mae']                  # Metrics for evaluation
)

# Train the model
history = model.fit(
    x_train, y_train,
    epochs=50,                       # Number of iterations
    batch_size=32,                   # Batch size
    validation_split=0.2             # Use 20% of the data for validation
)

# Evaluate the model
loss, mae = model.evaluate(x_train, y_train)
print(f"Loss: {loss}, MAE: {mae}")
# Out:
# Epoch 1/50
# /opt/homebrew/Caskroom/miniforge/base/envs/moe/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2620 - mae: 0.4214 - val_loss: 0.1049 - val_mae: 0.2735
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0868 - mae: 0.2447 - val_loss: 0.0873 - val_mae: 0.2509
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0825 - mae: 0.2437 - val_loss: 0.0866 - val_mae: 0.2490
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0848 - mae: 0.2453 - val_loss: 0.0853 - val_mae: 0.2494
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0789 - mae: 0.2376 - val_loss: 0.0858 - val_mae: 0.2502
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0834 - mae: 0.2465 - val_loss: 0.0846 - val_mae: 0.2471
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0780 - mae: 0.2365 - val_loss: 0.0862 - val_mae: 0.2503
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0832 - mae: 0.2449 - val_loss: 0.0845 - val_mae: 0.2470
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0786 - mae: 0.2387 - val_loss: 0.0838 - val_mae: 0.2448
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0841 - mae: 0.2500 - val_loss: 0.0849 - val_mae: 0.2474
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0796 - mae: 0.2417 - val_loss: 0.0846 - val_mae: 0.2468
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0736 - mae: 0.2275 - val_loss: 0.0847 - val_mae: 0.2466
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0763 - mae: 0.2337 - val_loss: 0.0877 - val_mae: 0.2517
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0740 - mae: 0.2311 - val_loss: 0.0848 - val_mae: 0.2465
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0682 - mae: 0.2180 - val_loss: 0.0838 - val_mae: 0.2452
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0731 - mae: 0.2301 - val_loss: 0.0840 - val_mae: 0.2452
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0786 - mae: 0.2412 - val_loss: 0.0843 - val_mae: 0.2447
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0765 - mae: 0.2323 - val_loss: 0.0870 - val_mae: 0.2487
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0719 - mae: 0.2275 - val_loss: 0.0833 - val_mae: 0.2426
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0696 - mae: 0.2222 - val_loss: 0.0829 - val_mae: 0.2419
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0705 - mae: 0.2252 - val_loss: 0.0838 - val_mae: 0.2434
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0696 - mae: 0.2252 - val_loss: 0.0835 - val_mae: 0.2425
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0666 - mae: 0.2171 - val_loss: 0.0887 - val_mae: 0.2499
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0707 - mae: 0.2265 - val_loss: 0.0840 - val_mae: 0.2427
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0707 - mae: 0.2252 - val_loss: 0.0854 - val_mae: 0.2459
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0679 - mae: 0.2186 - val_loss: 0.0843 - val_mae: 0.2436
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0690 - mae: 0.2258 - val_loss: 0.0861 - val_mae: 0.2465
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0641 - mae: 0.2131 - val_loss: 0.0922 - val_mae: 0.2529
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0684 - mae: 0.2203 - val_loss: 0.0850 - val_mae: 0.2445
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0642 - mae: 0.2116 - val_loss: 0.0880 - val_mae: 0.2483
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0669 - mae: 0.2198 - val_loss: 0.0865 - val_mae: 0.2466
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0608 - mae: 0.2078 - val_loss: 0.0849 - val_mae: 0.2456
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0597 - mae: 0.2060 - val_loss: 0.0894 - val_mae: 0.2501
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0649 - mae: 0.2133 - val_loss: 0.0869 - val_mae: 0.2474
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0608 - mae: 0.2086 - val_loss: 0.0871 - val_mae: 0.2469
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0607 - mae: 0.2059 - val_loss: 0.0874 - val_mae: 0.2482
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0619 - mae: 0.2088 - val_loss: 0.0883 - val_mae: 0.2487
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0632 - mae: 0.2117 - val_loss: 0.0897 - val_mae: 0.2502
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0574 - mae: 0.2001 - val_loss: 0.0931 - val_mae: 0.2538
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0612 - mae: 0.2088 - val_loss: 0.0918 - val_mae: 0.2523
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0579 - mae: 0.2026 - val_loss: 0.0893 - val_mae: 0.2513
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0615 - mae: 0.2100 - val_loss: 0.0930 - val_mae: 0.2543
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0584 - mae: 0.2005 - val_loss: 0.0924 - val_mae: 0.2539
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0560 - mae: 0.1969 - val_loss: 0.0906 - val_mae: 0.2520
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0561 - mae: 0.1955 - val_loss: 0.0908 - val_mae: 0.2534
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0550 - mae: 0.1955 - val_loss: 0.0916 - val_mae: 0.2543
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0537 - mae: 0.1931 - val_loss: 0.0924 - val_mae: 0.2545
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0522 - mae: 0.1891 - val_loss: 0.0931 - val_mae: 0.2549
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0552 - mae: 0.1936 - val_loss: 0.0920 - val_mae: 0.2548
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0512 - mae: 0.1903 - val_loss: 0.0951 - val_mae: 0.2573
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.0504 - mae: 0.1854
# Loss: 0.05859309807419777, MAE: 0.1983296424150467

# %%
# !pip install tensorflow
